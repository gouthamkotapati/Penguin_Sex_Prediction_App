# %%
import pandas as pd
import numpy as nd 
import matplotlib.pyplot as mb
from sklearn import tree,metrics

# %%
df=pd.read_csv("penguins_size.csv")

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...       3750.0    MALE
# 1    Adelie  Torgersen  ...       3800.0  FEMALE
# 2    Adelie  Torgersen  ...       3250.0  FEMALE
# 3    Adelie  Torgersen  ...          NaN     NaN
# 4    Adelie  Torgersen  ...       3450.0  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...          NaN     NaN
# 340  Gentoo     Biscoe  ...       4850.0  FEMALE
# 341  Gentoo     Biscoe  ...       5750.0    MALE
# 342  Gentoo     Biscoe  ...       5200.0  FEMALE
# 343  Gentoo     Biscoe  ...       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
df.describe(
    
)
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df["culmen_length_mm"].mean()
# Out:
# np.float64(43.9219298245614)

# %%
df["culmen_length_mm"]=df["culmen_length_mm"].fillna(df["culmen_length_mm"].mean())

# %%
df["culmen_length_mm"]
# Out:
# 0      39.10000
# 1      39.50000
# 2      40.30000
# 3      43.92193
# 4      36.70000
#          ...
# 339    43.92193
# 340    46.80000
# 341    50.40000
# 342    45.20000
# 343    49.90000
# Name: culmen_length_mm, Length: 344, dtype: float64

# %%
df["culmen_depth_mm"]=df["culmen_depth_mm"].fillna(df["culmen_depth_mm"].mean())

# %%
df["flipper_length_mm"]=df["flipper_length_mm"].fillna(df["flipper_length_mm"].mean())

# %%
df["body_mass_g"]=df["body_mass_g"].fillna(df["body_mass_g"].median())

# %%
df
# Out:
#     species     island  ...  body_mass_g     sex
# 0    Adelie  Torgersen  ...       3750.0    MALE
# 1    Adelie  Torgersen  ...       3800.0  FEMALE
# 2    Adelie  Torgersen  ...       3250.0  FEMALE
# 3    Adelie  Torgersen  ...       4050.0     NaN
# 4    Adelie  Torgersen  ...       3450.0  FEMALE
# ..      ...        ...  ...          ...     ...
# 339  Gentoo     Biscoe  ...       4050.0     NaN
# 340  Gentoo     Biscoe  ...       4850.0  FEMALE
# 341  Gentoo     Biscoe  ...       5750.0    MALE
# 342  Gentoo     Biscoe  ...       5200.0  FEMALE
# 343  Gentoo     Biscoe  ...       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
df["sex"].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
df["sex"]=df["sex"].replace(".","MALE")

# %%
df["sex"]
# Out:
# 0        MALE
# 1      FEMALE
# 2      FEMALE
# 3         NaN
# 4      FEMALE
#         ...
# 339       NaN
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: sex, Length: 344, dtype: object

# %%
df["sex"]=df['sex'].fillna("MALE")

# %%
df["sex"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 344 entries, 0 to 343
# Series name: sex
# Non-Null Count  Dtype
# --------------  -----
# 344 non-null    object
# dtypes: object(1)
# memory usage: 2.8+ KB

# %%
df["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df["species"]=df["species"].replace({"Adelie":0,"Gentoo":1,"Chinstrap":2})
# Out:
# C:\Users\Goutham\AppData\Local\Temp\ipykernel_4108\4239004730.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["species"]=df["species"].replace({"Adelie":0,"Gentoo":1,"Chinstrap":2})

# %%
df["species"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    1
# 340    1
# 341    1
# 342    1
# 343    1
# Name: species, Length: 344, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# MALE      179
# FEMALE    165
# Name: count, dtype: int64

# %%
df["island"]=df["island"].replace({"Biscoe":0,"Dream":1,"Torgersen":2})
# Out:
# C:\Users\Goutham\AppData\Local\Temp\ipykernel_4108\3503784213.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["island"]=df["island"].replace({"Biscoe":0,"Dream":1,"Torgersen":2})

# %%
df["sex"]=df["sex"].replace({"MALE":0,"FEMALE":1})
# Out:
# C:\Users\Goutham\AppData\Local\Temp\ipykernel_4108\1367413559.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["sex"]=df["sex"].replace({"MALE":0,"FEMALE":1})

# %%
df
# Out:
#      species  island  culmen_length_mm  ...  flipper_length_mm  body_mass_g  sex
# 0          0       2          39.10000  ...         181.000000       3750.0    0
# 1          0       2          39.50000  ...         186.000000       3800.0    1
# 2          0       2          40.30000  ...         195.000000       3250.0    1
# 3          0       2          43.92193  ...         200.915205       4050.0    0
# 4          0       2          36.70000  ...         193.000000       3450.0    1
# ..       ...     ...               ...  ...                ...          ...  ...
# 339        1       0          43.92193  ...         200.915205       4050.0    0
# 340        1       0          46.80000  ...         215.000000       4850.0    1
# 341        1       0          50.40000  ...         222.000000       5750.0    0
# 342        1       0          45.20000  ...         212.000000       5200.0    1
# 343        1       0          49.90000  ...         213.000000       5400.0    0
#
# [344 rows x 7 columns]

# %%
x=df.drop("sex",axis=1)
y=df['sex']

# %%
x[0:10]
# Out:
#    species  island  ...  flipper_length_mm  body_mass_g
# 0        0       2  ...         181.000000       3750.0
# 1        0       2  ...         186.000000       3800.0
# 2        0       2  ...         195.000000       3250.0
# 3        0       2  ...         200.915205       4050.0
# 4        0       2  ...         193.000000       3450.0
# 5        0       2  ...         190.000000       3650.0
# 6        0       2  ...         181.000000       3625.0
# 7        0       2  ...         195.000000       4675.0
# 8        0       2  ...         193.000000       3475.0
# 9        0       2  ...         190.000000       4250.0
#
# [10 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
y_train
# Out:
# 49     0
# 310    1
# 325    0
# 122    1
# 167    0
#       ..
# 323    0
# 192    0
# 117    0
# 47     0
# 172    1
# Name: sex, Length: 275, dtype: int64

# %%
y_test[0:10]
# Out:
# 141    0
# 6      1
# 60     1
# 249    0
# 54     1
# 312    1
# 126    1
# 215    0
# 252    1
# 100    1
# Name: sex, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=tree.predict(x_test)

# %%
y_pred[1:10]
# Out:
# array([0, 1, 0, 1, 1, 1, 0, 1, 1])

# %%
y_train
# Out:
# 49     0
# 310    1
# 325    0
# 122    1
# 167    0
#       ..
# 323    0
# 192    0
# 117    0
# 47     0
# 172    1
# Name: sex, Length: 275, dtype: int64

# %%
from sklearn.metrics import accuracy_score
test_acc=accuracy_score(y_test,y_pred)

# %%
print("accuracy_score",test_acc)
# Out:
# accuracy_score 0.8405797101449275

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[30  6]
#  [ 5 28]]

# %%
import pickle

# %%
with open('pen_model.pkl','wb')as file:
    pickle.dump(tree,file)
